# %%
import numpy as np
import pandas as pd
from wfa_cardinality_estimation_evaluation_framework.common import plotting

# %%
rs = np.random.RandomState(1)

df = pd.DataFrame({
    'num_sets': [_ for _ in range(2, 10)] * 10,
    'relative_error': rs.normal(scale=0.05, size=80)
})

ax = plotting.boxplot_relative_error(df, 'num_sets', 'relative_error')
